# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
pip uninstall django-model-utils
# Out:
# Found existing installation: django-model-utils 4.2.0
# Uninstalling django-model-utils-4.2.0:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/django_model_utils-4.2.0.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/model_utils/*
# Proceed (y/n)?

# %%
pip install django-model-utils
# Out:
# Collecting django-model-utils
#   Downloading django_model_utils-4.2.0-py3-none-any.whl (33 kB)
# Collecting Django>=2.0.1
#   Downloading Django-3.2.12-py3-none-any.whl (7.9 MB)
#      |████████████████████████████████| 7.9 MB 17.3 MB/s
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from Django>=2.0.1->django-model-utils) (2018.9)
# Collecting asgiref<4,>=3.3.2
#   Downloading asgiref-3.5.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: sqlparse>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from Django>=2.0.1->django-model-utils) (0.4.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from asgiref<4,>=3.3.2->Django>=2.0.1->django-model-utils) (3.10.0.2)
# Installing collected packages: asgiref, Django, django-model-utils
# Successfully installed Django-3.2.12 asgiref-3.5.0 django-model-utils-4.2.0

# %%
cd /gdrive/My Drive/Colab Notebooks/ML PRACTICAL/PCA
